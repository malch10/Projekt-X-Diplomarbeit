# %%
import pandas as pd
import os
import numpy as np

# Pfad zum Ordner setzen, der die Textdateien enthält
ordner_pfad = 'C:/Users/erikm/Desktop/Diplomarbeit Erik Marr/Daten/DatenSimulation'  # Ersetzen Sie dies mit dem tatsächlichen Pfad

# Liste, um die DataFrames zu speichern
df_list = pd.DataFrame()

df_x = []
df_y = []
df_t = []


df_x = pd.read_csv("C:/Users/erikm/Desktop/Diplomarbeit Erik Marr/Daten/DatenSimulation/Skalen/TPath_coorX.txt",delimiter='  ', engine='python' )
df_y = pd.read_csv("C:/Users/erikm/Desktop/Diplomarbeit Erik Marr/Daten/DatenSimulation/Skalen/TPath_coorY.txt",delimiter='  ', engine='python' )
df_t = pd.read_csv("C:/Users/erikm/Desktop/Diplomarbeit Erik Marr/Daten/DatenSimulation/Skalen/TPath_time.txt",delimiter='  ', engine='python' )
df_x_list = df_x.iloc[:, 0].tolist()
df_y_list = df_y.iloc[:, 0].tolist()
df_t_list = df_t.iloc[:, 0].tolist()

# %%
#df_x_list = [int(zahl) for zahl in df_x_list]


print(df_x_list)
# Out:
# [1e-05, 2e-05, 3e-05, 4e-05, 5e-05, 6e-05, 7e-05, 8e-05, 9e-05, 0.0001, 0.00011, 0.00012, 0.00013, 0.00014, 0.00015, 0.00016, 0.00017, 0.00018, 0.00019, 0.0002, 0.00021, 0.00022, 0.00023, 0.00024, 0.00025, 0.00026, 0.00027, 0.00028, 0.00029, 0.0003, 0.00031, 0.00032, 0.00033, 0.00034, 0.00035, 0.00036, 0.00037, 0.00038, 0.00039, 0.0004, 0.00041, 0.00042, 0.00043, 0.00044, 0.00045, 0.00046, 0.00047, 0.00048, 0.00049, 0.0005, 0.00051, 0.00052, 0.00053, 0.00054, 0.00055, 0.00056, 0.00057, 0.00058, 0.00059, 0.0006, 0.00061, 0.00062, 0.00063, 0.00064, 0.00065, 0.00066, 0.00067, 0.00068, 0.00069, 0.0007, 0.00071, 0.00072, 0.00073, 0.00074, 0.00075, 0.00076, 0.00077, 0.00078, 0.00079, 0.0008, 0.00081, 0.00082, 0.00083, 0.00084, 0.00085, 0.00086, 0.00087, 0.00088, 0.00089, 0.0009, 0.00091, 0.00092, 0.00093, 0.00094, 0.00095, 0.00096, 0.00097, 0.00098, 0.00099, 0.001, 0.00101, 0.00102, 0.00103, 0.00104, 0.00105, 0.00106, 0.00107, 0.00108, 0.00109, 0.0011, 0.00111, 0.00112, 0.00113, 0.00114, 0.00115, 0.00116, 0.00117, 0.00118, 0.00119, 0.0012, 0.00121, 0.00122, 0.00123, 0.00124, 0.00125, 0.00126, 0.00127, 0.00128, 0.00129, 0.0013, 0.00131, 0.00132, 0.00133, 0.00134, 0.00135, 0.00136, 0.00137, 0.00138, 0.00139, 0.0014, 0.00141, 0.00142, 0.00143, 0.00144, 0.00145, 0.00146, 0.00147, 0.00148, 0.00149, 0.0015, 0.00151, 0.00152, 0.00153, 0.00154, 0.00155, 0.00156, 0.00157, 0.00158, 0.00159, 0.0016, 0.00161, 0.00162, 0.00163, 0.00164, 0.00165, 0.00166, 0.00167, 0.00168, 0.00169, 0.0017, 0.00171, 0.00172, 0.00173, 0.00174, 0.00175, 0.00176, 0.00177, 0.00178, 0.00179, 0.0018, 0.00181, 0.00182, 0.00183, 0.00184, 0.00185, 0.00186, 0.00187, 0.00188, 0.00189, 0.0019, 0.00191, 0.00192, 0.00193, 0.00194, 0.00195, 0.00196, 0.00197, 0.00198, 0.00199, 0.002, 0.00201, 0.00202, 0.00203, 0.00204, 0.00205, 0.00206, 0.00207, 0.00208, 0.00209, 0.0021, 0.00211, 0.00212, 0.00213, 0.00214, 0.00215, 0.00216, 0.00217, 0.00218, 0.00219, 0.0022, 0.00221, 0.00222, 0.00223, 0.00224, 0.00225, 0.00226, 0.00227, 0.00228, 0.00229, 0.0023, 0.00231, 0.00232, 0.00233, 0.00234, 0.00235, 0.00236, 0.00237, 0.00238, 0.00239, 0.0024, 0.00241, 0.00242, 0.00243, 0.00244, 0.00245, 0.00246, 0.00247, 0.00248, 0.00249, 0.0025, 0.00251, 0.00252, 0.00253, 0.00254, 0.00255, 0.00256, 0.00257, 0.00258, 0.00259, 0.0026, 0.00261, 0.00262, 0.00263, 0.00264, 0.00265, 0.00266, 0.00267, 0.00268, 0.00269, 0.0027, 0.00271, 0.00272, 0.00273, 0.00274, 0.00275, 0.00276, 0.00277, 0.00278, 0.00279, 0.0028, 0.00281, 0.00282, 0.00283, 0.00284, 0.00285, 0.00286, 0.00287, 0.00288, 0.00289, 0.0029, 0.00291, 0.00292, 0.00293, 0.00294, 0.00295, 0.00296, 0.00297, 0.00298, 0.00299, 0.003]

# %%
for dateiname in os.listdir(ordner_pfad):
    if dateiname.startswith('TPath'):
        datei_pfad = os.path.join(ordner_pfad, dateiname)

    

        df = pd.read_csv(datei_pfad, delimiter='  ', engine='python')#,header=0, names=df_y_list)
        # Fügen Sie den DataFrame zur Liste hinzu
    
        #print(df)
        # Speichern der aktuellen Kopfzeile
        alte_kopfzeile = df.columns.tolist()
        
        # Erstellen einer neuen Kopfzeile
        neue_kopfzeile = df_y_list
        

        
        # Einfügen der alten Kopfzeile als erste Datenzeile
        df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
        df.index = df.index + 1  # Aktualisieren Sie den Index
        df.sort_index(inplace=True)  # Sortieren Sie den DataFrame neu
        df.columns = neue_kopfzeile
        
        # Zeigen des resultierenden DataFrame
        print(df)
        #print(df.iloc[1,1])
                # Hinzufügen der leeren Zeile am Anfang des DataFrame
        # df = pd.concat([new_row, df], ignore_index=True)    
        
        #new_headers = df_y_list
        #df.columns(new_headers)
        
        #print(df.head)
        # df = pd.DataFrame(columns=df_y_list)
        # 
        # #print(df)
        # 
        # melted_df = df.reset_index().melt(id_vars='index')

        #print(melted_df)
# Out:
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3092E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3278E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3456E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3623E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3782E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3932E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4072E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4201E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4316E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4423E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4524E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4618E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4705E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4786E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4860E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4928E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4989E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5044E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5096E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5143E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5187E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5226E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5261E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5291E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5317E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5340E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5357E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5371E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5381E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5389E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5393E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5396E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5395E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5392E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5387E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5378E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5367E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5354E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5339E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5322E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5304E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5285E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5264E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5241E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5217E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5192E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5164E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5136E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5107E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5076E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5046E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5014E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4982E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4949E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4915E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4880E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4845E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4809E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4773E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4737E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4700E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4663E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4626E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4588E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4551E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4513E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4475E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4437E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4399E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4361E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4323E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4285E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4247E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4209E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4172E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4134E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4097E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4059E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4022E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3985E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3949E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3913E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3877E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3841E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3805E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3770E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3735E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3701E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3667E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3633E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3599E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3566E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3533E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3501E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3469E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3437E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3406E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3375E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3345E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3314E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3285E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3255E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3227E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3198E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3170E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3142E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3115E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3088E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3061E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3035E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3010E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2984E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2959E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2935E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2911E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2887E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2864E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2841E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2818E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2796E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2774E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2753E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2732E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2711E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2691E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2671E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# ...
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5378E+02.1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5368E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5353E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5334E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5310E+02.1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5283E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5251E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5215E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5175E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5130E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5081E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5028E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4972E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4910E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4840E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4764E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4681E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4592E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4496E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4393E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4284E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4168E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4034E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3891E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3738E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3577E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3406E+02.1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3227E+02.1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.3038E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2840E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2633E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2452E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2422E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2391E+02.1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2361E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# C:\Users\erikm\AppData\Local\Temp\ipykernel_5128\2365028246.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2331E+02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0] = alte_kopfzeile  # Fügen Sie die alte Kopfzeile als neue Zeile hinzu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 23
#      21 df.index = df.index + 1  # Aktualisieren Sie den Index
#      22 df.sort_index(inplace=True)  # Sortieren Sie den DataFrame neu
# ---> 23 df.columns = neue_kopfzeile
#      25 # Zeigen des resultierenden DataFrame
#      26 print(df)
#
# File ~\Desktop\Diplomarbeit Erik Marr\Projekt X\venv\Lib\site-packages\pandas\core\generic.py:6307, in NDFrame.__setattr__(self, name, value)
#    6305 try:
#    6306     object.__getattribute__(self, name)
# -> 6307     return object.__setattr__(self, name, value)
#    6308 except AttributeError:
#    6309     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\Desktop\Diplomarbeit Erik Marr\Projekt X\venv\Lib\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
#     810 directly, e.g. `series.index = [1, 2, 3]`.
#     811 """
#     812 labels = ensure_index(labels)
# --> 813 self._mgr.set_axis(axis, labels)
#     814 self._clear_item_cache()
#
# File ~\Desktop\Diplomarbeit Erik Marr\Projekt X\venv\Lib\site-packages\pandas\core\internals\managers.py:239, in BaseBlockManager.set_axis(self, axis, new_labels)
#     237 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     238     # Caller is responsible for ensuring we have an Index object.
# --> 239     self._validate_set_axis(axis, new_labels)
#     240     self.axes[axis] = new_labels
#
# File ~\Desktop\Diplomarbeit Erik Marr\Projekt X\venv\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 401 elements, new values have 400 elements
